# %%
import os
import time
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import from_json, col

# For use in Chapter 9 - Data Sources
# https://mvnrepository.com/artifact/org.xerial/sqlite-jdbc
packages = "org.apache.spark:spark-sql-kafka-0-10_2.11:2.4.4"

os.environ["PYSPARK_SUBMIT_ARGS"] = (
    "--packages {0} pyspark-shell".format(packages)
)

def logLevel(spark):
    # REF: https://stackoverflow.com/questions/25193488/how-to-turn-off-info-logging-in-spark
    sc = spark.sparkContext
    log4jLogger = sc._jvm.org.apache.log4j
    log4jLogger.Logger.getLogger("org").setLevel(log4jLogger.Level.ERROR)
    log = log4jLogger.LogManager.getLogger(__name__)
    log.warn("Custom Warning")


spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Demo") \
    .getOrCreate()


logLevel(spark)

spark.sparkContext.setLogLevel("ERROR")

# %%
print(spark.range(5000).where("id > 500").selectExpr("sum(id)").collect())

df = spark.read.format("csv") \
    .option("header", "true") \
    .option("mode", "FAILFAST") \
    .load("file:" + os.getenv("OPTION3_HOME") + "/data/training_set.csv")

df.show(5)
# Out:
# [Row(sum(id)=12372250)]
# +---------+----------+--------+-----------+---------+--------+
# |object_id|       mjd|passband|       flux| flux_err|detected|
# +---------+----------+--------+-----------+---------+--------+
# |      615|59750.4229|       2|-544.810303| 3.622952|       1|
# |      615|59750.4306|       1|-816.434326| 5.553370|       1|
# |      615|59750.4383|       3|-471.385529| 3.801213|       1|
# |      615|59750.4450|       4|-388.984985|11.395031|       1|
# |      615|59752.4070|       2|-681.858887| 4.041204|       1|
# +---------+----------+--------+-----------+---------+--------+
# only showing top 5 rows

# %%
df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("startingOffsets", "latest") \
    .option("subscribe", "twitter_status_connect") \
    .load()


df.printSchema()

topicSchema = StructType() \
                .add("schema", StringType()) \
                .add("payload", StringType())


tweets = df.select(col("key").cast("string"),
            from_json(col("value").cast("string"), topicSchema))

print(type(tweets))
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)
#
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
streamQuery = tweets.writeStream\
                    .format("memory")\
                    .queryName("tweets_data")\
                    .outputMode("append")\
                    .start()

# %%
print(streamQuery.isActive)
# Out:
# True

# %%
for seconds in range(10):
    print("Refreshing....")
    spark.sql("""
      SELECT *
      FROM tweets_data
      """)\
      .show(5)
    time.sleep(2)

print(type(spark.sql(""" SELECT * FROM tweets_data """)))
# Out:
# Refreshing....
# +---+------------------------------------+
# |key|jsontostructs(CAST(value AS STRING))|
# +---+------------------------------------+
# +---+------------------------------------+
#
# Refreshing....
# +---+------------------------------------+
# |key|jsontostructs(CAST(value AS STRING))|
# +---+------------------------------------+
# +---+------------------------------------+
#
# Refreshing....
# +---+------------------------------------+
# |key|jsontostructs(CAST(value AS STRING))|
# +---+------------------------------------+
# +---+------------------------------------+
#
# Refreshing....
# +---+------------------------------------+
# |key|jsontostructs(CAST(value AS STRING))|
# +---+------------------------------------+
# +---+------------------------------------+
#
# Refreshing....
# +--------------------+------------------------------------+
# |                 key|jsontostructs(CAST(value AS STRING))|
# +--------------------+------------------------------------+
# |{"schema":{"type"...|                [{"type":"struct"...|
# +--------------------+------------------------------------+
#
# Refreshing....
# +--------------------+------------------------------------+
# |                 key|jsontostructs(CAST(value AS STRING))|
# +--------------------+------------------------------------+
# |{"schema":{"type"...|                [{"type":"struct"...|
# |{"schema":{"type"...|                [{"type":"struct"...|
# +--------------------+------------------------------------+
#
# Refreshing....
# +--------------------+------------------------------------+
# |                 key|jsontostructs(CAST(value AS STRING))|
# +--------------------+------------------------------------+
# |{"schema":{"type"...|                [{"type":"struct"...|
# |{"schema":{"type"...|                [{"type":"struct"...|
# +--------------------+------------------------------------+
#
# Refreshing....
# +--------------------+------------------------------------+
# |                 key|jsontostructs(CAST(value AS STRING))|
# +--------------------+------------------------------------+
# |{"schema":{"type"...|                [{"type":"struct"...|
# |{"schema":{"type"...|                [{"type":"struct"...|
# |{"schema":{"type"...|                [{"type":"struct"...|
# +--------------------+------------------------------------+
#
# Refreshing....
# +--------------------+------------------------------------+
# |                 key|jsontostructs(CAST(value AS STRING))|
# +--------------------+------------------------------------+
# |{"schema":{"type"...|                [{"type":"struct"...|
# |{"schema":{"type"...|                [{"type":"struct"...|
# |{"schema":{"type"...|                [{"type":"struct"...|
# +--------------------+------------------------------------+
#
# Refreshing....
# +--------------------+------------------------------------+
# |                 key|jsontostructs(CAST(value AS STRING))|
# +--------------------+------------------------------------+
# |{"schema":{"type"...|                [{"type":"struct"...|
# |{"schema":{"type"...|                [{"type":"struct"...|
# |{"schema":{"type"...|                [{"type":"struct"...|
# +--------------------+------------------------------------+
#
# <class 'pyspark.sql.dataframe.DataFrame'>

# %%
df = spark.sql(""" SELECT * FROM tweets_data """)

# %%
df.columns
# Out:
# ['key', 'jsontostructs(CAST(value AS STRING))']

# %%
df.select("jsontostructs(CAST(value AS STRING))").show(truncate=False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |jsontostructs(CAST(value AS STRING))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[{"type":"struct","fields":[{"type":"int64","optional":true,"name":"org.apache.kafka.connect.data.Timestamp","version":1,"doc":"Return the created_at","field":"CreatedAt"},{"type":"int64","optional":true,"doc":"Returns the id of the status","field":"Id"},{"type":"string","optional":true,"doc":"Returns the text of the status","field":"Text"},{"type":"string","optional":true,"doc":"Returns the source","field":"Source"},{"type":"boolean","optional":true,"doc":"Test if the status is truncated","field":"Truncated"},{"type":"int64","optional":true,"doc":"Returns the in_reply_tostatus_id","field":"InReplyToStatusId"},{"type":"int64","optional":true,"doc":"Returns the in_reply_user_id","field":"InReplyToUserId"},{"type":"string","optional":true,"doc":"Returns the in_reply_to_screen_name","field":"InReplyToScreenName"},{"type":"struct","fields":[{"type":"double","optional":false,"doc":"returns the latitude of the geo location","field":"Latitude"},{"type":"double","optional":false,"doc":"returns the longitude of the geo location","field":"Longitude"}],"optional":true,"name":"com.github.jcustenborder.kafka.connect.twitter.GeoLocation","doc":"Returns The location that this tweet refers to if available.","field":"GeoLocation"},{"type":"struct","fields":[{"type":"string","optional":true,"field":"Name"},{"type":"string","optional":true,"field":"StreetAddress"},{"type":"string","optional":true,"field":"CountryCode"},{"type":"string","optional":true,"field":"Id"},{"type":"string","optional":true,"field":"Country"},{"type":"string","optional":true,"field":"PlaceType"},{"type":"string","optional":true,"field":"URL"},{"type":"string","optional":true,"field":"FullName"}],"optional":true,"name":"com.github.jcustenborder.kafka.connect.twitter.Place","doc":"Returns the place attached to this status","field":"Place"},{"type":"boolean","optional":true,"doc":"Test if the status is favorited","field":"Favorited"},{"type":"boolean","optional":true,"doc":"Test if the status is retweeted","field":"Retweeted"},{"type":"int32","optional":true,"doc":"Indicates approximately how many times this Tweet has been \"favorited\" by Twitter users.","field":"FavoriteCount"},{"type":"struct","fields":[{"type":"int64","optional":true,"doc":"Returns the id of the user","field":"Id"},{"type":"string","optional":true,"doc":"Returns the name of the user","field":"Name"},{"type":"string","optional":true,"doc":"Returns the screen name of the user","field":"ScreenName"},{"type":"string","optional":true,"doc":"Returns the location of the user","field":"Location"},{"type":"string","optional":true,"doc":"Returns the description of the user","field":"Description"},{"type":"boolean","optional":true,"doc":"Tests if the user is enabling contributors","field":"ContributorsEnabled"},{"type":"string","optional":true,"doc":"Returns the profile image url of the user","field":"ProfileImageURL"},{"type":"string","optional":true,"field":"BiggerProfileImageURL"},{"type":"string","optional":true,"field":"MiniProfileImageURL"},{"type":"string","optional":true,"field":"OriginalProfileImageURL"},{"type":"string","optional":true,"field":"ProfileImageURLHttps"},{"type":"string","optional":true,"field":"BiggerProfileImageURLHttps"},{"type":"string","optional":true,"field":"MiniProfileImageURLHttps"},{"type":"string","optional":true,"field":"OriginalProfileImageURLHttps"},{"type":"boolean","optional":true,"doc":"Tests if the user has not uploaded their own avatar","field":"DefaultProfileImage"},{"type":"string","optional":true,"doc":"Returns the url of the user","field":"URL"},{"type":"boolean","optional":true,"doc":"Test if the user status is protected","field":"Protected"},{"type":"int32","optional":true,"doc":"Returns the number of followers","field":"FollowersCount"},{"type":"string","optional":true,"field":"ProfileBackgroundColor"},{"type":"string","optional":true,"field":"ProfileTextColor"},{"type":"string","optional":true,"field":"ProfileLinkColor"},{"type":"string","optional":true,"field":"Pr ...
# |[{"type":"struct","fields":[{"type":"int64","optional":true,"name":"org.apache.kafka.connect.data.Timestamp","version":1,"doc":"Return the created_at","field":"CreatedAt"},{"type":"int64","optional":true,"doc":"Returns the id of the status","field":"Id"},{"type":"string","optional":true,"doc":"Returns the text of the status","field":"Text"},{"type":"string","optional":true,"doc":"Returns the source","field":"Source"},{"type":"boolean","optional":true,"doc":"Test if the status is truncated","field":"Truncated"},{"type":"int64","optional":true,"doc":"Returns the in_reply_tostatus_id","field":"InReplyToStatusId"},{"type":"int64","optional":true,"doc":"Returns the in_reply_user_id","field":"InReplyToUserId"},{"type":"string","optional":true,"doc":"Returns the in_reply_to_screen_name","field":"InReplyToScreenName"},{"type":"struct","fields":[{"type":"double","optional":false,"doc":"returns the latitude of the geo location","field":"Latitude"},{"type":"double","optional":false,"doc":"returns the longitude of the geo location","field":"Longitude"}],"optional":true,"name":"com.github.jcustenborder.kafka.connect.twitter.GeoLocation","doc":"Returns The location that this tweet refers to if available.","field":"GeoLocation"},{"type":"struct","fields":[{"type":"string","optional":true,"field":"Name"},{"type":"string","optional":true,"field":"StreetAddress"},{"type":"string","optional":true,"field":"CountryCode"},{"type":"string","optional":true,"field":"Id"},{"type":"string","optional":true,"field":"Country"},{"type":"string","optional":true,"field":"PlaceType"},{"type":"string","optional":true,"field":"URL"},{"type":"string","optional":true,"field":"FullName"}],"optional":true,"name":"com.github.jcustenborder.kafka.connect.twitter.Place","doc":"Returns the place attached to this status","field":"Place"},{"type":"boolean","optional":true,"doc":"Test if the status is favorited","field":"Favorited"},{"type":"boolean","optional":true,"doc":"Test if the status is retweeted","field":"Retweeted"},{"type":"int32","optional":true,"doc":"Indicates approximately how many times this Tweet has been \"favorited\" by Twitter users.","field":"FavoriteCount"},{"type":"struct","fields":[{"type":"int64","optional":true,"doc":"Returns the id of the user","field":"Id"},{"type":"string","optional":true,"doc":"Returns the name of the user","field":"Name"},{"type":"string","optional":true,"doc":"Returns the screen name of the user","field":"ScreenName"},{"type":"string","optional":true,"doc":"Returns the location of the user","field":"Location"},{"type":"string","optional":true,"doc":"Returns the description of the user","field":"Description"},{"type":"boolean","optional":true,"doc":"Tests if the user is enabling contributors","field":"ContributorsEnabled"},{"type":"string","optional":true,"doc":"Returns the profile image url of the user","field":"ProfileImageURL"},{"type":"string","optional":true,"field":"BiggerProfileImageURL"},{"type":"string","optional":true,"field":"MiniProfileImageURL"},{"type":"string","optional":true,"field":"OriginalProfileImageURL"},{"type":"string","optional":true,"field":"ProfileImageURLHttps"},{"type":"string","optional":true,"field":"BiggerProfileImageURLHttps"},{"type":"string","optional":true,"field":"MiniProfileImageURLHttps"},{"type":"string","optional":true,"field":"OriginalProfileImageURLHttps"},{"type":"boolean","optional":true,"doc":"Tests if the user has not uploaded their own avatar","field":"DefaultProfileImage"},{"type":"string","optional":true,"doc":"Returns the url of the user","field":"URL"},{"type":"boolean","optional":true,"doc":"Test if the user status is protected","field":"Protected"},{"type":"int32","optional":true,"doc":"Returns the number of followers","field":"FollowersCount"},{"type":"string","optional":true,"field":"ProfileBackgroundColor"},{"type":"string","optional":true,"field":"ProfileTextColor"},{"type":"string","optional":true,"field":"ProfileLinkColor"},{"type":"string","optional":true,"field":"Pr ...
# |[{"type":"struct","fields":[{"type":"int64","optional":true,"name":"org.apache.kafka.connect.data.Timestamp","version":1,"doc":"Return the created_at","field":"CreatedAt"},{"type":"int64","optional":true,"doc":"Returns the id of the status","field":"Id"},{"type":"string","optional":true,"doc":"Returns the text of the status","field":"Text"},{"type":"string","optional":true,"doc":"Returns the source","field":"Source"},{"type":"boolean","optional":true,"doc":"Test if the status is truncated","field":"Truncated"},{"type":"int64","optional":true,"doc":"Returns the in_reply_tostatus_id","field":"InReplyToStatusId"},{"type":"int64","optional":true,"doc":"Returns the in_reply_user_id","field":"InReplyToUserId"},{"type":"string","optional":true,"doc":"Returns the in_reply_to_screen_name","field":"InReplyToScreenName"},{"type":"struct","fields":[{"type":"double","optional":false,"doc":"returns the latitude of the geo location","field":"Latitude"},{"type":"double","optional":false,"doc":"returns the longitude of the geo location","field":"Longitude"}],"optional":true,"name":"com.github.jcustenborder.kafka.connect.twitter.GeoLocation","doc":"Returns The location that this tweet refers to if available.","field":"GeoLocation"},{"type":"struct","fields":[{"type":"string","optional":true,"field":"Name"},{"type":"string","optional":true,"field":"StreetAddress"},{"type":"string","optional":true,"field":"CountryCode"},{"type":"string","optional":true,"field":"Id"},{"type":"string","optional":true,"field":"Country"},{"type":"string","optional":true,"field":"PlaceType"},{"type":"string","optional":true,"field":"URL"},{"type":"string","optional":true,"field":"FullName"}],"optional":true,"name":"com.github.jcustenborder.kafka.connect.twitter.Place","doc":"Returns the place attached to this status","field":"Place"},{"type":"boolean","optional":true,"doc":"Test if the status is favorited","field":"Favorited"},{"type":"boolean","optional":true,"doc":"Test if the status is retweeted","field":"Retweeted"},{"type":"int32","optional":true,"doc":"Indicates approximately how many times this Tweet has been \"favorited\" by Twitter users.","field":"FavoriteCount"},{"type":"struct","fields":[{"type":"int64","optional":true,"doc":"Returns the id of the user","field":"Id"},{"type":"string","optional":true,"doc":"Returns the name of the user","field":"Name"},{"type":"string","optional":true,"doc":"Returns the screen name of the user","field":"ScreenName"},{"type":"string","optional":true,"doc":"Returns the location of the user","field":"Location"},{"type":"string","optional":true,"doc":"Returns the description of the user","field":"Description"},{"type":"boolean","optional":true,"doc":"Tests if the user is enabling contributors","field":"ContributorsEnabled"},{"type":"string","optional":true,"doc":"Returns the profile image url of the user","field":"ProfileImageURL"},{"type":"string","optional":true,"field":"BiggerProfileImageURL"},{"type":"string","optional":true,"field":"MiniProfileImageURL"},{"type":"string","optional":true,"field":"OriginalProfileImageURL"},{"type":"string","optional":true,"field":"ProfileImageURLHttps"},{"type":"string","optional":true,"field":"BiggerProfileImageURLHttps"},{"type":"string","optional":true,"field":"MiniProfileImageURLHttps"},{"type":"string","optional":true,"field":"OriginalProfileImageURLHttps"},{"type":"boolean","optional":true,"doc":"Tests if the user has not uploaded their own avatar","field":"DefaultProfileImage"},{"type":"string","optional":true,"doc":"Returns the url of the user","field":"URL"},{"type":"boolean","optional":true,"doc":"Test if the user status is protected","field":"Protected"},{"type":"int32","optional":true,"doc":"Returns the number of followers","field":"FollowersCount"},{"type":"string","optional":true,"field":"ProfileBackgroundColor"},{"type":"string","optional":true,"field":"ProfileTextColor"},{"type":"string","optional":true,"field":"ProfileLinkColor"},{"type":"string","optional":true,"field":"Pr ...
# |[{"type":"struct","fields":[{"type":"int64","optional":true,"name":"org.apache.kafka.connect.data.Timestamp","version":1,"doc":"Return the created_at","field":"CreatedAt"},{"type":"int64","optional":true,"doc":"Returns the id of the status","field":"Id"},{"type":"string","optional":true,"doc":"Returns the text of the status","field":"Text"},{"type":"string","optional":true,"doc":"Returns the source","field":"Source"},{"type":"boolean","optional":true,"doc":"Test if the status is truncated","field":"Truncated"},{"type":"int64","optional":true,"doc":"Returns the in_reply_tostatus_id","field":"InReplyToStatusId"},{"type":"int64","optional":true,"doc":"Returns the in_reply_user_id","field":"InReplyToUserId"},{"type":"string","optional":true,"doc":"Returns the in_reply_to_screen_name","field":"InReplyToScreenName"},{"type":"struct","fields":[{"type":"double","optional":false,"doc":"returns the latitude of the geo location","field":"Latitude"},{"type":"double","optional":false,"doc":"returns the longitude of the geo location","field":"Longitude"}],"optional":true,"name":"com.github.jcustenborder.kafka.connect.twitter.GeoLocation","doc":"Returns The location that this tweet refers to if available.","field":"GeoLocation"},{"type":"struct","fields":[{"type":"string","optional":true,"field":"Name"},{"type":"string","optional":true,"field":"StreetAddress"},{"type":"string","optional":true,"field":"CountryCode"},{"type":"string","optional":true,"field":"Id"},{"type":"string","optional":true,"field":"Country"},{"type":"string","optional":true,"field":"PlaceType"},{"type":"string","optional":true,"field":"URL"},{"type":"string","optional":true,"field":"FullName"}],"optional":true,"name":"com.github.jcustenborder.kafka.connect.twitter.Place","doc":"Returns the place attached to this status","field":"Place"},{"type":"boolean","optional":true,"doc":"Test if the status is favorited","field":"Favorited"},{"type":"boolean","optional":true,"doc":"Test if the status is retweeted","field":"Retweeted"},{"type":"int32","optional":true,"doc":"Indicates approximately how many times this Tweet has been \"favorited\" by Twitter users.","field":"FavoriteCount"},{"type":"struct","fields":[{"type":"int64","optional":true,"doc":"Returns the id of the user","field":"Id"},{"type":"string","optional":true,"doc":"Returns the name of the user","field":"Name"},{"type":"string","optional":true,"doc":"Returns the screen name of the user","field":"ScreenName"},{"type":"string","optional":true,"doc":"Returns the location of the user","field":"Location"},{"type":"string","optional":true,"doc":"Returns the description of the user","field":"Description"},{"type":"boolean","optional":true,"doc":"Tests if the user is enabling contributors","field":"ContributorsEnabled"},{"type":"string","optional":true,"doc":"Returns the profile image url of the user","field":"ProfileImageURL"},{"type":"string","optional":true,"field":"BiggerProfileImageURL"},{"type":"string","optional":true,"field":"MiniProfileImageURL"},{"type":"string","optional":true,"field":"OriginalProfileImageURL"},{"type":"string","optional":true,"field":"ProfileImageURLHttps"},{"type":"string","optional":true,"field":"BiggerProfileImageURLHttps"},{"type":"string","optional":true,"field":"MiniProfileImageURLHttps"},{"type":"string","optional":true,"field":"OriginalProfileImageURLHttps"},{"type":"boolean","optional":true,"doc":"Tests if the user has not uploaded their own avatar","field":"DefaultProfileImage"},{"type":"string","optional":true,"doc":"Returns the url of the user","field":"URL"},{"type":"boolean","optional":true,"doc":"Test if the user status is protected","field":"Protected"},{"type":"int32","optional":true,"doc":"Returns the number of followers","field":"FollowersCount"},{"type":"string","optional":true,"field":"ProfileBackgroundColor"},{"type":"string","optional":true,"field":"ProfileTextColor"},{"type":"string","optional":true,"field":"ProfileLinkColor"},{"type":"string","optional":true,"field":"Pr ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...

# %%
streamQuery.stop()
# streamQuery.awaitTermination()

# %%
payload = df.toPandas()["jsontostructs(CAST(value AS STRING))"][0].asDict()['payload']
# Out:
# /usr/local/Cellar/apache-spark/2.4.5/libexec/python/pyspark/sql/dataframe.py:2110: UserWarning: toPandas attempted Arrow optimization because 'spark.sql.execution.arrow.enabled' is set to true; however, failed by the reason below:
#   Unsupported type in conversion to Arrow: StructType(List(StructField(schema,StringType,true),StructField(payload,StringType,true)))
# Attempting non-optimization as 'spark.sql.execution.arrow.fallback.enabled' is set to true.
#   warnings.warn(msg)

# %%
type(payload)
# Out:
# str

# %%
import json    # or `import simplejson as json` if on Python < 2.6

json_string = payload
obj = json.loads(json_string)

# %%
pp = json.loads(df.toPandas()["jsontostructs(CAST(value AS STRING))"][2].asDict()['payload'])
pp
# Out:
# {'CreatedAt': 1590315405000,
#  'Id': 1264500577507012609,
#  'Text': 'RT @MoudNsui: .@nsui is not just a frontal organisation of a political party , but it’s an ideology having an amalgamation of patriotism wi…',
#  'Source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'Truncated': False,
#  'InReplyToStatusId': -1,
#  'InReplyToUserId': -1,
#  'InReplyToScreenName': None,
#  'GeoLocation': None,
#  'Place': None,
#  'Favorited': False,
#  'Retweeted': False,
#  'FavoriteCount': 0,
#  'User': {'Id': 1210460605712224256,
#   'Name': 'Prabudha Devkar',
#   'ScreenName': 'PrabudhaD',
#   'Location': None,
#   'Description': 'Be Yourself bcz an original is always worth more then a copy ... #Engg .. \n#DBOSS fan ..',
#   'ContributorsEnabled': False,
#   'ProfileImageURL': 'http://pbs.twimg.com/profile_images/1227955330992070658/u62IFkPu_normal.jpg',
#   'BiggerProfileImageURL': 'http://pbs.twimg.com/profile_images/1227955330992070658/u62IFkPu_bigger.jpg',
#   'MiniProfileImageURL': 'http://pbs.twimg.com/profile_images/1227955330992070658/u62IFkPu_mini.jpg',
#   'OriginalProfileImageURL': 'http://pbs.twimg.com/profile_images/1227955330992070658/u62IFkPu.jpg',
#   'ProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1227955330992070658/u62IFkPu_normal.jpg',
#   'BiggerProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1227955330992070658/u62IFkPu_bigger.jpg',
#   'MiniProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1227955330992070658/u62IFkPu_mini.jpg',
#   'OriginalProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1227955330992070658/u62IFkPu.jpg',
#   'DefaultProfileImage': False,
#   'URL': None,
#   'Protected': False,
#   'FollowersCount': 10,
#   'ProfileBackgroundColor': 'F5F8FA',
#   'ProfileTextColor': '333333',
#   'ProfileLinkColor': '1DA1F2',
#   'ProfileSidebarFillColor': 'DDEEF6',
#   'ProfileSidebarBorderColor': 'C0DEED',
#   'ProfileUseBackgroundImage': True,
#   'DefaultProfile': True,
#   'ShowAllInlineMedia': False,
#   'FriendsCount': 90,
#   'CreatedAt': 1577431324000,
#   'FavouritesCount': 2989,
#   'UtcOffset': -1,
#   'TimeZone': None,
#   'ProfileBackgroundImageURL': '',
#   'ProfileBackgroundImageUrlHttps': '',
#   'ProfileBannerURL': None,
#   'ProfileBannerRetinaURL': None,
#   'ProfileBannerIPadURL': None,
#   'ProfileBannerIPadRetinaURL': None,
#   'ProfileBannerMobileURL': None,
#   'ProfileBannerMobileRetinaURL': None,
#   'ProfileBackgroundTiled': False,
#   'Lang': None,
#   'StatusesCount': 3272,
#   'GeoEnabled': False,
#   'Verified': False,
#   'Translator': False,
#   'ListedCount': 0,
#   'FollowRequestSent': False,
#   'WithheldInCountries': []},
#  'Retweet': True,
#  'Contributors': [],
#  'RetweetCount': 0,
#  'RetweetedByMe': False,
#  'CurrentUserRetweetId': -1,
#  'PossiblySensitive': False,
#  'Lang': 'en',
#  'WithheldInCountries': [],
#  'HashtagEntities': [],
#  'UserMentionEntities': [{'Name': 'Nitish moud Nsui Chittorgarh',
#    'Id': 962609375931121664,
#    'Text': 'MoudNsui',
#    'ScreenName': 'MoudNsui',
#    'Start': 3,
#    'End': 12},
#   {'Name': 'NSUI',
#    'Id': 16323656,
#    'Text': 'nsui',
#    'ScreenName': 'nsui',
#    'Start': 15,
#    'End': 20}],
#  'MediaEntities': [],
#  'SymbolEntities': [],
#  'URLEntities': []}

# %%
obj.keys()
# Out:
# dict_keys(['CreatedAt', 'Id', 'Text', 'Source', 'Truncated', 'InReplyToStatusId', 'InReplyToUserId', 'InReplyToScreenName', 'GeoLocation', 'Place', 'Favorited', 'Retweeted', 'FavoriteCount', 'User', 'Retweet', 'Contributors', 'RetweetCount', 'RetweetedByMe', 'CurrentUserRetweetId', 'PossiblySensitive', 'Lang', 'WithheldInCountries', 'HashtagEntities', 'UserMentionEntities', 'MediaEntities', 'SymbolEntities', 'URLEntities'])

# %%
obj
# Out:
# {'CreatedAt': 1590315399000,
#  'Id': 1264500549766074373,
#  'Text': 'Current thought \n\nOverly nice people with perfect lives very often have something to hide, what is presented as a happy look at me in my perfect world is usually a very sad place!\n\nSomeone with a spark, troubles and tribulations who strives for success is far more appeasing!',
#  'Source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'Truncated': True,
#  'InReplyToStatusId': -1,
#  'InReplyToUserId': -1,
#  'InReplyToScreenName': None,
#  'GeoLocation': None,
#  'Place': None,
#  'Favorited': False,
#  'Retweeted': False,
#  'FavoriteCount': 0,
#  'User': {'Id': 3427893292,
#   'Name': 'BlueBell_369 💋',
#   'ScreenName': 'Bluebell_369',
#   'Location': 'London',
#   'Description': None,
#   'ContributorsEnabled': False,
#   'ProfileImageURL': 'http://pbs.twimg.com/profile_images/1036157158260391936/g7K96oek_normal.jpg',
#   'BiggerProfileImageURL': 'http://pbs.twimg.com/profile_images/1036157158260391936/g7K96oek_bigger.jpg',
#   'MiniProfileImageURL': 'http://pbs.twimg.com/profile_images/1036157158260391936/g7K96oek_mini.jpg',
#   'OriginalProfileImageURL': 'http://pbs.twimg.com/profile_images/1036157158260391936/g7K96oek.jpg',
#   'ProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1036157158260391936/g7K96oek_normal.jpg',
#   'BiggerProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1036157158260391936/g7K96oek_bigger.jpg',
#   'MiniProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1036157158260391936/g7K96oek_mini.jpg',
#   'OriginalProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1036157158260391936/g7K96oek.jpg',
#   'DefaultProfileImage': False,
#   'URL': None,
#   'Protected': False,
#   'FollowersCount': 1642,
#   'ProfileBackgroundColor': 'C0DEED',
#   'ProfileTextColor': '333333',
#   'ProfileLinkColor': '1DA1F2',
#   'ProfileSidebarFillColor': 'DDEEF6',
#   'ProfileSidebarBorderColor': 'C0DEED',
#   'ProfileUseBackgroundImage': True,
#   'DefaultProfile': True,
#   'ShowAllInlineMedia': False,
#   'FriendsCount': 1650,
#   'CreatedAt': 1439808398000,
#   'FavouritesCount': 61562,
#   'UtcOffset': -1,
#   'TimeZone': None,
#   'ProfileBackgroundImageURL': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'ProfileBackgroundImageUrlHttps': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'ProfileBannerURL': 'https://pbs.twimg.com/profile_banners/3427893292/1535876071/web',
#   'ProfileBannerRetinaURL': 'https://pbs.twimg.com/profile_banners/3427893292/1535876071/web_retina',
#   'ProfileBannerIPadURL': 'https://pbs.twimg.com/profile_banners/3427893292/1535876071/ipad',
#   'ProfileBannerIPadRetinaURL': 'https://pbs.twimg.com/profile_banners/3427893292/1535876071/ipad_retina',
#   'ProfileBannerMobileURL': 'https://pbs.twimg.com/profile_banners/3427893292/1535876071/mobile',
#   'ProfileBannerMobileRetinaURL': 'https://pbs.twimg.com/profile_banners/3427893292/1535876071/mobile_retina',
#   'ProfileBackgroundTiled': False,
#   'Lang': None,
#   'StatusesCount': 56026,
#   'GeoEnabled': False,
#   'Verified': False,
#   'Translator': False,
#   'ListedCount': 5,
#   'FollowRequestSent': False,
#   'WithheldInCountries': []},
#  'Retweet': False,
#  'Contributors': [],
#  'RetweetCount': 0,
#  'RetweetedByMe': False,
#  'CurrentUserRetweetId': -1,
#  'PossiblySensitive': False,
#  'Lang': 'en',
#  'WithheldInCountries': [],
#  'HashtagEntities': [],
#  'UserMentionEntities': [],
#  'MediaEntities': [],
#  'SymbolEntities': [],
#  'URLEntities': []}

# %% [markdown]
# VIDEO

# %%
df = spark \
    .readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("startingOffsets", "latest") \
    .option("subscribe", "twitter_status_connect") \
    .load()


df.printSchema()

topicSchema = StructType() \
                .add("schema", StringType()) \
                .add("payload", StringType())


tweets = df.select(col("key").cast("string"),
                    from_json(col("value").cast("string"), topicSchema).alias("data"), 
                    col("timestamp"))\
                    .writeStream\
                    .format("memory")\
                    .queryName("tweets_data")\
                    .outputMode("update")\
                    .start()
print(type(tweets))
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)
#
# <class 'pyspark.sql.streaming.StreamingQuery'>

# %%
type(tweets)
# Out:
# pyspark.sql.streaming.StreamingQuery

# %%
tweets.isActive
# Out:
# True

# %%
df = spark.sql(""" SELECT * FROM tweets_data """)

# %%
df.select('data', 'timestamp').show(truncate=False)
# Out:
# +----+---------+
# |data|timestamp|
# +----+---------+
# +----+---------+

# %%
df.count()
# Out:
# 21

# %%
df = df.orderBy("timestamp", ascending=False)

# %%
df = df.limit(1)
df.show()
# Out:
# +--------------------+--------------------+--------------------+
# |                 key|                data|           timestamp|
# +--------------------+--------------------+--------------------+
# |{"schema":{"type"...|[{"type":"struct"...|2020-05-24 16:42:...|
# +--------------------+--------------------+--------------------+

# %%
# spark.catalog.clearCache()

# %%
df.toPandas()['data'][0].asDict()["payload"]
# Out:
# '{"CreatedAt":1590334979000,"Id":1264582677900005376,"Text":"RT @romanoffnparker: I love spark notes https://t.co/tQI4d70FDN","Source":"<a href=\\"http://twitter.com/download/android\\" rel=\\"nofollow\\">Twitter for Android</a>","Truncated":false,"InReplyToStatusId":-1,"InReplyToUserId":-1,"InReplyToScreenName":null,"GeoLocation":null,"Place":null,"Favorited":false,"Retweeted":false,"FavoriteCount":0,"User":{"Id":2368240250,"Name":"Michael Lewis","ScreenName":"myfanpleasure","Location":"Dallas, TX","Description":"Place to express my fandom.  I love Doctor Who, RP video games, and cosplayers.","ContributorsEnabled":false,"ProfileImageURL":"http://pbs.twimg.com/profile_images/1166211143817469953/3cDs5gcL_normal.jpg","BiggerProfileImageURL":"http://pbs.twimg.com/profile_images/1166211143817469953/3cDs5gcL_bigger.jpg","MiniProfileImageURL":"http://pbs.twimg.com/profile_images/1166211143817469953/3cDs5gcL_mini.jpg","OriginalProfileImageURL":"http://pbs.twimg.com/profile_images/1166211143817469953/3cDs5gcL.jpg","ProfileImageURLHttps":"https://pbs.twimg.com/profile_images/1166211143817469953/3cDs5gcL_normal.jpg","BiggerProfileImageURLHttps":"https://pbs.twimg.com/profile_images/1166211143817469953/3cDs5gcL_bigger.jpg","MiniProfileImageURLHttps":"https://pbs.twimg.com/profile_images/1166211143817469953/3cDs5gcL_mini.jpg","OriginalProfileImageURLHttps":"https://pbs.twimg.com/profile_images/1166211143817469953/3cDs5gcL.jpg","DefaultProfileImage":false,"URL":null,"Protected":false,"FollowersCount":536,"ProfileBackgroundColor":"C0DEED","ProfileTextColor":"333333","ProfileLinkColor":"1DA1F2","ProfileSidebarFillColor":"DDEEF6","ProfileSidebarBorderColor":"C0DEED","ProfileUseBackgroundImage":true,"DefaultProfile":true,"ShowAllInlineMedia":false,"FriendsCount":268,"CreatedAt":1393732695000,"FavouritesCount":15191,"UtcOffset":-1,"TimeZone":null,"ProfileBackgroundImageURL":"http://abs.twimg.com/images/themes/theme1/bg.png","ProfileBackgroundImageUrlHttps":"https://abs.twimg.com/images/themes/theme1/bg.png","ProfileBannerURL":"https://pbs.twimg.com/profile_banners/2368240250/1561394708/web","ProfileBannerRetinaURL":"https://pbs.twimg.com/profile_banners/2368240250/1561394708/web_retina","ProfileBannerIPadURL":"https://pbs.twimg.com/profile_banners/2368240250/1561394708/ipad","ProfileBannerIPadRetinaURL":"https://pbs.twimg.com/profile_banners/2368240250/1561394708/ipad_retina","ProfileBannerMobileURL":"https://pbs.twimg.com/profile_banners/2368240250/1561394708/mobile","ProfileBannerMobileRetinaURL":"https://pbs.twimg.com/profile_banners/2368240250/1561394708/mobile_retina","ProfileBackgroundTiled":false,"Lang":null,"StatusesCount":53404,"GeoEnabled":false,"Verified":false,"Translator":false,"ListedCount":26,"FollowRequestSent":false,"WithheldInCountries":[]},"Retweet":true,"Contributors":[],"RetweetCount":0,"RetweetedByMe":false,"CurrentUserRetweetId":-1,"PossiblySensitive":false,"Lang":"en","WithheldInCountries":[],"HashtagEntities":[],"UserMentionEntities":[{"Name":"Trisha ⧗","Id":899472069083181057,"Text":"romanoffnparker","ScreenName":"romanoffnparker","Start":3,"End":19}],"MediaEntities":[{"Id":1264492561227382784,"Type":"photo","MediaURL":"http://pbs.twimg.com/media/EYxhSO0VAAAi0Ek.jpg","Sizes":[[0,{"Resize":101,"Width":150,"Height":150}],[1,{"Resize":100,"Width":510,"Height":680}],[2,{"Resize":100,"Width":900,"Height":1200}],[3,{"Resize":100,"Width":1536,"Height":2048}]],"MediaURLHttps":"https://pbs.twimg.com/media/EYxhSO0VAAAi0Ek.jpg","VideoAspectRatioWidth":0,"VideoAspectRatioHeight":0,"VideoDurationMillis":0,"VideoVariants":[],"ExtAltText":null,"URL":"https://t.co/tQI4d70FDN","Text":"https://t.co/tQI4d70FDN","ExpandedURL":"https://twitter.com/romanoffnparker/status/1264492597961056257/photo/1","Start":40,"End":63,"DisplayURL":"pic.twitter.com/tQI4d70FDN"},{"Id":1264492568005369857,"Type":"photo","MediaURL":"http://pbs.twimg.com/media/EYxhSoEU4AEWbtV.jpg","Sizes":[[0,{"Resize":101,"Width":150,"Height":150}],[1,{"Resize":100,"Width":510 ...

# %%
payload = json.loads(df.toPandas()["data"][0].asDict()["payload"])

# %%
payload.get('Text')
# Out:
# 'RT @romanoffnparker: I love spark notes https://t.co/tQI4d70FDN'

# %%
geo = payload.get('GeoLocation', None)
print(geo)
# Out:
# None

# %%
df.count()
# Out:
# 1

# %%
type(df.toPandas()["data"])
datadf = df.toPandas()["data"].to_frame()
df.toPandas()["data"][0].asDict()["payload"]
# Out:
# '{"CreatedAt":1590331785000,"Id":1264569281464995844,"Text":"RT @Chadd_McClain: When a nigga spark a mid blunt n da club \\uD83D\\uDE12\\uD83D\\uDEAB\\uD83D\\uDE45\\uD83C\\uDFFD\u200d♂️✌\\uD83C\\uDFFE✋\\uD83C\\uDFFD\\uD83E\\uDD26\\uD83C\\uDFFE\u200d♂️ https://t.co/J9kyqCWt79","Source":"<a href=\\"http://twitter.com/download/iphone\\" rel=\\"nofollow\\">Twitter for iPhone</a>","Truncated":false,"InReplyToStatusId":-1,"InReplyToUserId":-1,"InReplyToScreenName":null,"GeoLocation":null,"Place":null,"Favorited":false,"Retweeted":false,"FavoriteCount":0,"User":{"Id":294347885,"Name":"DJ Chadìco Papìto \\uD83E\\uDD2C\\uD83D\\uDD25\\uD83D\\uDCB8\\uD83D\\uDD0C","ScreenName":"Chadd_McClain","Location":"E/S of Blatlanta ","Description":"Father Of Prince Ayden. Papi Pancho! Envisionist Known by Errbody who matters! #LL21OneOne #LLZoot #LLDMapp #LLRadd","ContributorsEnabled":false,"ProfileImageURL":"http://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_normal.jpg","BiggerProfileImageURL":"http://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_bigger.jpg","MiniProfileImageURL":"http://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_mini.jpg","OriginalProfileImageURL":"http://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF.jpg","ProfileImageURLHttps":"https://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_normal.jpg","BiggerProfileImageURLHttps":"https://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_bigger.jpg","MiniProfileImageURLHttps":"https://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_mini.jpg","OriginalProfileImageURLHttps":"https://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF.jpg","DefaultProfileImage":false,"URL":"https://mymixtapez.com/album/202212","Protected":false,"FollowersCount":6592,"ProfileBackgroundColor":"131516","ProfileTextColor":"333333","ProfileLinkColor":"000000","ProfileSidebarFillColor":"EFEFEF","ProfileSidebarBorderColor":"EEEEEE","ProfileUseBackgroundImage":true,"DefaultProfile":false,"ShowAllInlineMedia":false,"FriendsCount":4161,"CreatedAt":1304727291000,"FavouritesCount":29949,"UtcOffset":-1,"TimeZone":null,"ProfileBackgroundImageURL":"http://abs.twimg.com/images/themes/theme1/bg.png","ProfileBackgroundImageUrlHttps":"https://abs.twimg.com/images/themes/theme1/bg.png","ProfileBannerURL":"https://pbs.twimg.com/profile_banners/294347885/1369058788/web","ProfileBannerRetinaURL":"https://pbs.twimg.com/profile_banners/294347885/1369058788/web_retina","ProfileBannerIPadURL":"https://pbs.twimg.com/profile_banners/294347885/1369058788/ipad","ProfileBannerIPadRetinaURL":"https://pbs.twimg.com/profile_banners/294347885/1369058788/ipad_retina","ProfileBannerMobileURL":"https://pbs.twimg.com/profile_banners/294347885/1369058788/mobile","ProfileBannerMobileRetinaURL":"https://pbs.twimg.com/profile_banners/294347885/1369058788/mobile_retina","ProfileBackgroundTiled":true,"Lang":null,"StatusesCount":35954,"GeoEnabled":true,"Verified":false,"Translator":false,"ListedCount":16,"FollowRequestSent":false,"WithheldInCountries":[]},"Retweet":true,"Contributors":[],"RetweetCount":0,"RetweetedByMe":false,"CurrentUserRetweetId":-1,"PossiblySensitive":false,"Lang":"en","WithheldInCountries":[],"HashtagEntities":[],"UserMentionEntities":[{"Name":"DJ Chadìco Papìto \\uD83E\\uDD2C\\uD83D\\uDD25\\uD83D\\uDCB8\\uD83D\\uDD0C","Id":294347885,"Text":"Chadd_McClain","ScreenName":"Chadd_McClain","Start":3,"End":17}],"MediaEntities":[{"Id":869962725425729536,"Type":"animated_gif","MediaURL":"http://pbs.twimg.com/tweet_video_thumb/DBK6fVDU0AAPo4F.jpg","Sizes":[[0,{"Resize":101,"Width":150,"Height":150}],[1,{"Resize":100,"Width":200,"Height":150}],[2,{"Resize":100,"Width":200,"Height":150}],[3,{"Resize":100,"Width":200,"Height":150}]],"MediaURLHttps":"https://pbs.twimg.com/tweet_video_thumb/DBK6fVDU0AAPo4F.jpg","VideoAspectRatioWidth":4,"VideoAspectRatioHeight":3,"VideoDurationMillis":0,"VideoVariants":[{"Url":"https://video.twimg.com/tweet_video/DBK6fVDU0AAPo ...

# %%
for i in range(df.count()):
    try:
        payload = json.loads(df.toPandas()["data"][i].asDict()["payload"])
        print(payload)
        if payload["GeoLocation"] != None:
            print(payload["GeoLocation"])
    except Exception as e:
        print(repr(e))
        continue
# Out:
# /usr/local/Cellar/apache-spark/2.4.5/libexec/python/pyspark/sql/dataframe.py:2110: UserWarning: toPandas attempted Arrow optimization because 'spark.sql.execution.arrow.enabled' is set to true; however, failed by the reason below:
#   Unsupported type in conversion to Arrow: StructType(List(StructField(schema,StringType,true),StructField(payload,StringType,true)))
# Attempting non-optimization as 'spark.sql.execution.arrow.fallback.enabled' is set to true.
#   warnings.warn(msg)
# {'CreatedAt': 1590331785000, 'Id': 1264569281464995844, 'Text': 'RT @Chadd_McClain: When a nigga spark a mid blunt n da club 😒🚫🙅🏽\u200d♂️✌🏾✋🏽🤦🏾\u200d♂️ https://t.co/J9kyqCWt79', 'Source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'Truncated': False, 'InReplyToStatusId': -1, 'InReplyToUserId': -1, 'InReplyToScreenName': None, 'GeoLocation': None, 'Place': None, 'Favorited': False, 'Retweeted': False, 'FavoriteCount': 0, 'User': {'Id': 294347885, 'Name': 'DJ Chadìco Papìto 🤬🔥💸🔌', 'ScreenName': 'Chadd_McClain', 'Location': 'E/S of Blatlanta ', 'Description': 'Father Of Prince Ayden. Papi Pancho! Envisionist Known by Errbody who matters! #LL21OneOne #LLZoot #LLDMapp #LLRadd', 'ContributorsEnabled': False, 'ProfileImageURL': 'http://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_normal.jpg', 'BiggerProfileImageURL': 'http://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_bigger.jpg', 'MiniProfileImageURL': 'http://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_mini.jpg', 'OriginalProfileImageURL': 'http://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF.jpg', 'ProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_normal.jpg', 'BiggerProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_bigger.jpg', 'MiniProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF_mini.jpg', 'OriginalProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1102705096008351744/wiswgLYF.jpg', 'DefaultProfileImage': False, 'URL': 'https://mymixtapez.com/album/202212', 'Protected': False, 'FollowersCount': 6592, 'ProfileBackgroundColor': '131516', 'ProfileTextColor': '333333', 'ProfileLinkColor': '000000', 'ProfileSidebarFillColor': 'EFEFEF', 'ProfileSidebarBorderColor': 'EEEEEE', 'ProfileUseBackgroundImage': True, 'DefaultProfile': False, 'ShowAllInlineMedia': False, 'FriendsCount': 4161, 'CreatedAt': 1304727291000, 'FavouritesCount': 29949, 'UtcOffset': -1, 'TimeZone': None, 'ProfileBackgroundImageURL': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'ProfileBackgroundImageUrlHttps': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'ProfileBannerURL': 'https://pbs.twimg.com/profile_banners/294347885/1369058788/web', 'ProfileBannerRetinaURL': 'https://pbs.twimg.com/profile_banners/294347885/1369058788/web_retina', 'ProfileBannerIPadURL': 'https://pbs.twimg.com/profile_banners/294347885/1369058788/ipad', 'ProfileBannerIPadRetinaURL': 'https://pbs.twimg.com/profile_banners/294347885/1369058788/ipad_retina', 'ProfileBannerMobileURL': 'https://pbs.twimg.com/profile_banners/294347885/1369058788/mobile', 'ProfileBannerMobileRetinaURL': 'https://pbs.twimg.com/profile_banners/294347885/1369058788/mobile_retina', 'ProfileBackgroundTiled': True, 'Lang': None, 'StatusesCount': 35954, 'GeoEnabled': True, 'Verified': False, 'Translator': False, 'ListedCount': 16, 'FollowRequestSent': False, 'WithheldInCountries': []}, 'Retweet': True, 'Contributors': [], 'RetweetCount': 0, 'RetweetedByMe': False, 'CurrentUserRetweetId': -1, 'PossiblySensitive': False, 'Lang': 'en', 'WithheldInCountries': [], 'HashtagEntities': [], 'UserMentionEntities': [{'Name': 'DJ Chadìco Papìto 🤬🔥💸🔌', 'Id': 294347885, 'Text': 'Chadd_McClain', 'ScreenName': 'Chadd_McClain', 'Start': 3, 'End': 17}], 'MediaEntities': [{'Id': 869962725425729536, 'Type': 'animated_gif', 'MediaURL': 'http://pbs.twimg.com/tweet_video_thumb/DBK6fVDU0AAPo4F.jpg', 'Sizes': [[0, {'Resize': 101, 'Width': 150, 'Height': 150}], [1, {'Resize': 100, 'Width': 200, 'Height': 150}], [2, {'Resize': 100, 'Width': 200, 'Height': 150}], [3, {'Resize': 100, 'Width': 200, 'Height': 150}]], 'MediaURLHttps': 'https://pbs.twimg.com/tweet_video_thumb/DBK6fVDU0AAPo4F.jpg', 'VideoAspectRatioWidth': 4, 'VideoAspectRatioHeight': 3, 'VideoDurationMillis': 0, 'VideoVariants': [{'Url': 'https://video.twimg.com/tweet_video/DBK6fVDU0AAPo4F.mp4', 'Bitrate ...
# {'CreatedAt': 1590331786000, 'Id': 1264569282601480192, 'Text': '福浦は苦笑いしてました(汗)\n#SPARK', 'Source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'Truncated': False, 'InReplyToStatusId': 1264569139709874176, 'InReplyToUserId': 383798607, 'InReplyToScreenName': '40LEOTOH_1983', 'GeoLocation': None, 'Place': None, 'Favorited': False, 'Retweeted': False, 'FavoriteCount': 0, 'User': {'Id': 383798607, 'Name': '4 0 L 党@Leolution！ 今季はリーグ３連覇・日本一奪還！！', 'ScreenName': '40LEOTOH_1983', 'Location': None, 'Description': '何よりも埼玉西武ライオンズが好き。オレたちの#1 栗山巧を敬愛。パシフィックリーグ２連覇を誇ろう！！！今季こそは日本一奪還！！来たれライオンズ黄金時代！！\n\nMLBはSEA(菊池雄星)CIN(秋山翔吾)を応援。今季も辻発彦監督と渡辺久信GMを全面支持\n\n球団マスコットやゆるキャラ好き。ライオンズポンタをやってます', 'ContributorsEnabled': False, 'ProfileImageURL': 'http://pbs.twimg.com/profile_images/1253715508911730690/3EIBfn_2_normal.jpg', 'BiggerProfileImageURL': 'http://pbs.twimg.com/profile_images/1253715508911730690/3EIBfn_2_bigger.jpg', 'MiniProfileImageURL': 'http://pbs.twimg.com/profile_images/1253715508911730690/3EIBfn_2_mini.jpg', 'OriginalProfileImageURL': 'http://pbs.twimg.com/profile_images/1253715508911730690/3EIBfn_2.jpg', 'ProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1253715508911730690/3EIBfn_2_normal.jpg', 'BiggerProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1253715508911730690/3EIBfn_2_bigger.jpg', 'MiniProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1253715508911730690/3EIBfn_2_mini.jpg', 'OriginalProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1253715508911730690/3EIBfn_2.jpg', 'DefaultProfileImage': False, 'URL': None, 'Protected': False, 'FollowersCount': 707, 'ProfileBackgroundColor': 'C0DEED', 'ProfileTextColor': '333333', 'ProfileLinkColor': '1DA1F2', 'ProfileSidebarFillColor': 'DDEEF6', 'ProfileSidebarBorderColor': 'C0DEED', 'ProfileUseBackgroundImage': True, 'DefaultProfile': True, 'ShowAllInlineMedia': False, 'FriendsCount':
 'ProfileBackgroundColor': 'F5F8FA', 'ProfileTextColor': '333333', 'ProfileLinkColor': '1DA1F2', 'ProfileSidebarFillColor': 'DDEEF6', 'ProfileSidebarBorderColor': 'C0DEED', 'ProfileUseBackgroundImage': True, 'DefaultProfile': True, 'ShowAllInlineMedia': False, 'FriendsCount': 303, 'CreatedAt': 1512568082000, 'FavouritesCount': 14321, 'UtcOffset': -1, 'TimeZone': None, 'ProfileBackgroundImageURL': '', 'ProfileBackgroundImageUrlHttps': '', 'ProfileBannerURL': 'https://pbs.twimg.com/profile_banners/938404670321463296/1590209311/web', 'ProfileBannerRetinaURL': 'https://pbs.twimg.com/profile_banners/938404670321463296/1590209311/web_retina', 'ProfileBannerIPadURL': 'https://pbs.twimg.com/profile_banners/938404670321463296/1590209311/ipad', 'ProfileBannerIPadRetinaURL': 'https://pbs.twimg.com/profile_banners/938404670321463296/1590209311/ipad_retina', 'ProfileBannerMobileURL': 'https://pbs.twimg.com/profile_banners/938404670321463296/1590209311/mobile', 'ProfileBannerMobileRetinaURL': 'https://pbs.twimg.com/profile_banners/938404670321463296/1590209311/mobile_retina', 'ProfileBackgroundTiled': False, 'Lang': None, 'StatusesCount': 16383, 'GeoEnabled': False, 'Verified': False, 'Translator': False, 'ListedCount': 0, 'FollowRequestSent': False, 'WithheldInCountries': []}, 'Retweet': False, 'Contributors': [], 'RetweetCount': 0, 'RetweetedByMe': False, 'CurrentUserRetweetId': -1, 'PossiblySensitive': False, 'Lang': 'en', 'WithheldInCountries': [], 'HashtagEntities': [], 'UserMentionEntities': [], 'MediaEntities': [{'Id': 1264569784517050369, 'Type': 'photo', 'MediaURL': 'http://pbs.twimg.com/media/EYynhN_UwAEUi7U.jpg', 'Sizes': [[0, {'Resize': 101, 'Width': 150, 'Height': 150}], [1, {'Resize': 100, 'Width': 382, 'Height': 680}], [2, {'Resize': 100, 'Width': 675, 'Height': 1200}], [3, {'Resize': 100, 'Width': 750, 'Height': 1334}]], 'MediaURLHttps': 'https://pbs.twimg.com/media/EYynhN_UwAEUi7U.jpg', 'VideoAspectRatioWidth': 0, 'VideoAspectRatioHeight': 0, 'VideoDurationMillis': 0, 'VideoVariants': [], 'ExtAltText': None, 'URL': 'https://t.co/hBzyaT6kY1', 'Text': 'https://t.co/hBzyaT6kY1', 'ExpandedURL': 'https://twitter.com/Tstephhaniie/status/1264569793253801986/photo/1', 'Start': 12, 'End': 35, 'DisplayURL': 'pic.twitter.com/hBzyaT6kY1'}, {'Id': 1264569784517054465, 'Type': 'photo', 'MediaURL': 'http://pbs.twimg.com/media/EYynhN_U0AEc3Hs.jpg', 'Sizes': [[0, {'Resize': 101, 'Width': 150, 'Height': 150}], [1, {'Resize': 100, 'Width': 382, 'Height': 680}], [2, {'Resize': 100, ...
# {'CreatedAt': 1590331908000, 'Id': 1264569796282265603, 'Text': "@AshleyRoboto I feel you. Between loss of personal motivation and overwork, it's hard to find that joyous spark inside that inspires me to make content.\nEven so, you're still posting motivational and funny content frequently, and that always perks me up! Take your time.", 'Source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'Truncated': True, 'InReplyToStatusId': 1264339373216202752, 'InReplyToUserId': 355995137, 'InReplyToScreenName': 'AshleyRoboto', 'GeoLocation': None, 'Place': None, 'Favorited': False, 'Retweeted': False, 'FavoriteCount': 0, 'User': {'Id': 923585902173151232, 'Name': 'Michela Dee 🖤 Black Eagles 🖤', 'ScreenName': 'micheladlondon', 'Location': None, 'Description': 'Soulsborne enthusiast and ancient cosplayer with a love of history, gaming, cosmetics, and art. Professional and hobbyist content creator. 🏳️\u200d🌈', 'ContributorsEnabled': False, 'ProfileImageURL': 'http://pbs.twimg.com/profile_images/1239051474228981760/Pv7lXrvW_normal.jpg', 'BiggerProfileImageURL': 'http://pbs.twimg.com/profile_images/1239051474228981760/Pv7lXrvW_bigger.jpg', 'MiniProfileImageURL': 'http://pbs.twimg.com/profile_images/1239051474228981760/Pv7lXrvW_mini.jpg', 'OriginalProfileImageURL': 'http://pbs.twimg.com/profile_images/1239051474228981760/Pv7lXrvW.jpg', 'ProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1239051474228981760/Pv7lXrvW_normal.jpg', 'BiggerProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1239051474228981760/Pv7lXrvW_bigger.jpg', 'MiniProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1239051474228981760/Pv7lXrvW_mini.jpg', 'OriginalProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1239051474228981760/Pv7lXrvW.jpg', 'DefaultProfileImage': False, 'URL': 'https://www.youtube.com/user/Michela', 'Protected': False, 'FollowersCount': 790, 'ProfileBackgroundColor': '000000', 'ProfileTextColor': '000000', 'ProfileLinkColor': '981CEB', 'ProfileSidebarFillColor': '000000', 'ProfileSidebarBorderColor': '000000', 'ProfileUseBackgroundImage': False, 'DefaultProfile': False, 'ShowAllInlineMedia': False, 'FriendsCount': 1020, 'CreatedAt': 1509035013000, 'FavouritesCount': 43572, 'UtcOffset': -1, 'TimeZone': None, 'ProfileBackgroundImageURL': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'ProfileBackgroundImageUrlHttps': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'ProfileBannerURL': 'https://pbs.twimg.com/profile_banners/923585902173151232/1509037066/web', 'ProfileBannerRetinaURL': 'https://pbs.twimg.com/profile_banners/923585902173151232/1509037066/web_retina', 'ProfileBannerIPadURL': 'https://pbs.twimg.com/profile_banners/923585902173151232/1509037066/ipad', 'ProfileBannerIPadRetinaURL': 'https://pbs.twimg.com/profile_banners/923585902173151232/1509037066/ipad_retina', 'ProfileBannerMobileURL': 'https://pbs.twimg.com/profile_banners/923585902173151232/1509037066/mobile', 'ProfileBannerMobileRetinaURL': 'https://pbs.twimg.com/profile_banners/923585902173151232/1509037066/mobile_retina', 'ProfileBackgroundTiled': False, 'Lang': None, 'StatusesCount': 11610, 'GeoEnabled': True, 'Verified': False, 'Translator': False, 'ListedCount': 2, 'FollowRequestSent': False, 'WithheldInCountries': []}, 'Retweet': False, 'Contributors': [], 'RetweetCount': 0, 'RetweetedByMe': False, 'CurrentUserRetweetId': -1, 'PossiblySensitive': False, 'Lang': 'en', 'WithheldInCountries': [], 'HashtagEntities': [], 'UserMentionEntities': [{'Name': 'Ashley ✧・ﾟ', 'Id': 355995137, 'Text': 'AshleyRoboto', 'ScreenName': 'AshleyRoboto', 'Start': 0, 'End': 13}], 'MediaEntities': [], 'SymbolEntities': [], 'URLEntities': []}
# {'CreatedAt': 1590331917000, 'Id': 1264569833741586433, 'Text': 'zhuoxuan really just made smth spark in me,,,,,,,,,,, that motivation and confidence ughhhh', 'Source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'Truncated': False, 'InReplyToStatusId': -1, 'InReplyToUserId': -1, 'InReplyToScreenName': None, 'GeoLocation': None, 'Place': None, 'Favorited': False, 'Retweeted': False, 'FavoriteCount': 0, 'User': {'Id': 1145429321437331456, 'Name': '𝐦𝐢𝐫𝐚', 'ScreenName': 'starryjyani', 'Location': ' she/they + minor ', 'Description': '🇮🇩🏳️\u200d🌈 | currently watching produce camp 2020 | art account- @daisyjhwn', 'ContributorsEnabled': False, 'ProfileImageURL': 'http://pbs.twimg.com/profile_images/1263759897914757121/jLwl_VKw_normal.jpg', 'BiggerProfileImageURL': 'http://pbs.twimg.com/profile_images/1263759897914757121/jLwl_VKw_bigger.jpg', 'MiniProfileImageURL': 'http://pbs.twimg.com/profile_images/1263759897914757121/jLwl_VKw_mini.jpg', 'OriginalProfileImageURL': 'http://pbs.twimg.com/profile_images/1263759897914757121/jLwl_VKw.jpg', 'ProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1263759897914757121/jLwl_VKw_normal.jpg', 'BiggerProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1263759897914757121/jLwl_VKw_bigger.jpg', 'MiniProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1263759897914757121/jLwl_VKw_mini.jpg', 'OriginalProfileImageURLHttps': 'https://pbs.twimg.com/profile_images/1263759897914757121/jLwl_VKw.jpg', 'DefaultProfileImage': False, 'URL': 'https://www.instagram.com/mira.artworks/', 'Protected': False, 'FollowersCount': 286, 'ProfileBackgroundColor': 'F5F8FA', 'ProfileTextColor': '333333', 'ProfileLinkColor': '1DA1F2', 'ProfileSidebarFillColor': 'DDEEF6', 'ProfileSidebarBorderColor': 'C0DEED', 'ProfileUseBackgroundImage': True, 'DefaultProfile': True, 'ShowAllInlineMedia': False, 'FriendsCount': 284, 'CreatedAt': 1561926606000, 'FavouritesCount': 5515, 'UtcOffset': -1, 'TimeZone': None, 'ProfileBackgroundImageURL': '', 'ProfileBackgroundImageUrlHttps': '', 'ProfileBannerURL': 'https://pbs.twimg.com/profile_banners/1145429321437331456/1589500813/web', 'ProfileBannerRetinaURL': 'https://pbs.twimg.com/profile_banners/1145429321437331456/1589500813/web_retina', 'ProfileBannerIPadURL': 'https://pbs.twimg.com/profile_banners/1145429321437331456/1589500813/ipad', 'ProfileBannerIPadRetinaURL': 'https://pbs.twimg.com/profile_banners/1145429321437331456/1589500813/ipad_retina', 'ProfileBannerMobileURL': 'https://pbs.twimg.com/profile_banners/1145429321437331456/1589500813/mobile', 'ProfileBannerMobileRetinaURL': 'https://pbs.twimg.com/profile_banners/1145429321437331456/1589500813/mobile_retina', 'ProfileBackgroundTiled': False, 'Lang': None, 'StatusesCount': 5628, 'GeoEnabled': False, 'Verified': False, 'Translator': False, 'ListedCount': 11, 'FollowRequestSent': False, 'WithheldInCountries': []}, 'Retweet': False, 'Contributors': [], 'RetweetCount': 0, 'RetweetedByMe': False, 'CurrentUserRetweetId': -1, 'PossiblySensitive': False, 'Lang': 'en', 'WithheldInCountries': [], 'HashtagEntities': [], 'UserMentionEntities': [], 'MediaEntities': [], 'SymbolEntities': [], 'URLEntities': []}
# KeyError(29)
# KeyError(30)
# KeyError(31)
# KeyError(32)
# KeyError(33)
# KeyError(34)
# KeyError(35)
# KeyError(36)
# KeyError(37)
# KeyError(38)
# KeyError(39)
# KeyError(40)
# KeyError(41)
# KeyError(42)
# KeyError(43)
# KeyError(44)
# KeyError(45)
# KeyError(46)
# KeyError(47)
# KeyError(48)
# KeyError(49)
# KeyError(50)
# KeyError(51)
# KeyError(52)
# KeyError(53)
# KeyError(54)
# KeyError(55)
# KeyError(56)
# KeyError(57)
# KeyError(58)
# KeyError(59)
# KeyError(60)
# KeyError(61)
# KeyError(62)
# KeyError(63)
# KeyError(64)
# KeyError(65)
# KeyError(66)
# KeyError(67)
# KeyError(68)
# KeyError(69)
# KeyError(70)
# KeyError(71)
# KeyError(72)
# KeyError(73)
# KeyError(74)
# KeyError(75)
# KeyError(76)
# KeyError(77)
# KeyError(78)
# KeyError(79)
# KeyError(80)
# KeyError(81)
# KeyError(82)
# KeyError(83)
# KeyError(84)
# KeyError(85)
# KeyError(86)
# KeyError(87)
# KeyError(88)
# KeyError(89)
# KeyError(90)
# KeyError(91)
# KeyError(92)
# KeyError(93)
# KeyError(94)
# KeyError(95)
# KeyError(96)
# KeyError(97)
# KeyError(98)
# KeyError(99)
# KeyError(100)
# KeyError(101)
# KeyError(102)
# KeyError(103)
# KeyError(104)
# KeyError(105)
# KeyError(106)
# KeyError(107)
# KeyError(108)
# KeyError(109)
# KeyError(110)
# KeyError(111)
# KeyError(112)
# KeyError(113)
# KeyError(114)
# KeyError(115)
# KeyError(116)
# KeyError(117)
# KeyError(118)
# KeyError(119)
# KeyError(120)
# KeyError(121)
# KeyError(122)
# KeyError(123)
# KeyError(124)
# KeyError(125)
# KeyError(126)
# KeyError(127)
# KeyError(128)
# KeyError(129)
# KeyError(130)
# KeyError(131)
# KeyError(132)
# KeyError(133)
# KeyError(134)
# KeyError(135)
# KeyError(136)
# KeyError(137)
# KeyError(138)
# KeyError(139)
# KeyError(140)
# KeyError(141)
# KeyError(142)
# KeyError(143)
# KeyError(144)
# KeyError(145)
# KeyError(146)
# KeyError(147)
# KeyError(148)
# KeyError(149)
# KeyError(150)
# KeyError(151)
# KeyError(152)
# KeyError(153)
# KeyError(154)
# KeyError(155)
# KeyError(156)
# KeyError(157)
# KeyError(158)
# KeyError(159)
# KeyError(160)
# KeyError(161)
# KeyError(162)
# KeyError(163)
# KeyError(164)
# KeyError(165)
# KeyError(166)
# KeyError(167)
# KeyError(168)
# KeyError(169)
# KeyError(170)
# KeyError(171)
# KeyError(172)
# KeyError(173)
# KeyError(174)
# KeyError(175)
# KeyError(176)
# KeyError(177)
# KeyError(178)
# KeyError(179)
# KeyError(180)
# KeyError(181)
# KeyError(182)
# KeyError(183)
# KeyError(184)
# KeyError(185)
# KeyError(186)
# KeyError(187)
# KeyError(188)
# KeyError(189)
# KeyError(190)
# KeyError(191)
# KeyError(192)
# KeyError(193)
# KeyError(194)
# KeyError(195)
# KeyError(196)
# KeyError(197)
# KeyError(198)
# KeyError(199)
# KeyError(200)
# KeyError(201)
# KeyError(202)
# KeyError(203)
# KeyError(204)
# KeyError(205)
# KeyError(206)
# KeyError(207)
# KeyError(208)
# KeyError(209)
# KeyError(210)
# KeyError(211)
# KeyError(212)
# KeyError(213)
# KeyError(214)
# KeyError(215)
# KeyError(216)
# KeyError(217)
# KeyError(218)
# KeyError(219)
# KeyError(220)
# KeyError(221)
# KeyError(222)
# KeyError(223)
# KeyError(224)
# KeyError(225)
# KeyError(226)
# KeyError(227)
# KeyError(228)
# KeyError(229)
# KeyError(230)
# KeyError(231)
# KeyError(232)
# KeyError(233)
# KeyError(234)
# KeyError(235)
# KeyError(236)
# KeyError(237)
# KeyError(238)
# KeyError(239)
# KeyError(240)
# KeyError(241)
# KeyError(242)
# KeyError(243)
# KeyError(244)
# KeyError(245)
# KeyError(246)
# KeyError(247)
# KeyError(248)
# KeyError(249)
# KeyError(250)
# KeyError(251)

# %%
tweets.stop()
